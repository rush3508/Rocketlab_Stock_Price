# %% [markdown]
# <a href="https://colab.research.google.com/github/rush3508/Rocketlab_Stock_Price/blob/main/LSTM_plus_Attn_Adv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow -qqq
# !pip install keras -qqq
# !pip install yfinance -qqq

# %%
import tensorflow as tf
import keras
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Check TensorFlow version
print("TensorFlow Version: ", tf.__version__)
# Out:
# TensorFlow Version:  2.15.0

# %%
# Fetch AAPL data
aapl_data = yf.download('AAPL', start='2020-01-01', end='2024-01-01')

# Display the first few rows of the dataframe
aapl_data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  72.960442  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.251144  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  72.826851  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.484352  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.650345  132079200
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Open'].plot(kind='hist', bins=20, title='Open')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['High'].plot(kind='hist', bins=20, title='High')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Low'].plot(kind='hist', bins=20, title='Low')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Close'].plot(kind='hist', bins=20, title='Close')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Open', y='High', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='High', y='Low', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Low', y='Close', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Close', y='Adj Close', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['Open'].plot(kind='line', figsize=(8, 4), title='Open')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['High'].plot(kind='line', figsize=(8, 4), title='High')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['Low'].plot(kind='line', figsize=(8, 4), title='Low')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Close'].plot(kind='line', figsize=(8, 4), title='Close')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Checking for missing values
aapl_data.isnull().sum()

# Filling missing values, if any
aapl_data.fillna(method='ffill', inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
aapl_data_scaled = scaler.fit_transform(aapl_data['Close'].values.reshape(-1,1))

# %%
X = []
y = []

for i in range(60, len(aapl_data_scaled)):
    X.append(aapl_data_scaled[i-60:i, 0])
    y.append(aapl_data_scaled[i, 0])

# %%
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size

X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# from keras.models import Sequential
# from keras.layers import LSTM, Dense, Dropout

# # Model initialization
# model = Sequential()

# # Adding the first LSTM layer
# model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))

# # Adding additional LSTM layers
# model.add(LSTM(units=50, return_sequences=True))
# model.add(LSTM(units=50))

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

model = Sequential()

# Adding LSTM layers
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(units=50, return_sequences=True))
model.add(LSTM(units=50, return_sequences=False))  # Only the last time step

# Adding a Dense layer to match the output shape with y_train
model.add(Dense(1))

# Compiling the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Training the model
history = model.fit(X_train, y_train, epochs=100, batch_size=25, validation_split=0.2)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 17s 135ms/step - loss: 0.0528 - val_loss: 0.0101
# Epoch 2/100
# 25/25 [==============================] - 0s 20ms/step - loss: 0.0056 - val_loss: 0.0025
# Epoch 3/100
# 25/25 [==============================] - 1s 34ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 4/100
# 25/25 [==============================] - 1s 26ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 5/100
# 25/25 [==============================] - 1s 24ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 6/100
# 25/25 [==============================] - 1s 23ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 7/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 8/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 9/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 10/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 11/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0020 - val_loss: 0.0033
# Epoch 12/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 13/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 14/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 15/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 16/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 17/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 0.0038
# Epoch 18/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 19/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 20/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 21/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 22/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 23/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 24/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 25/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 26/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 27/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 28/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 29/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 30/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 31/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 32/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 33/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 34/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 35/100
# 25/25 [==============================] - 0s 13ms/step - loss: 9.2277e-04 - val_loss: 0.0011
# Epoch 36/100
# 25/25 [==============================] - 0s 13ms/step - loss: 8.9643e-04 - val_loss: 9.9655e-04
# Epoch 37/100
# 25/25 [==============================] - 0s 14ms/step - loss: 9.2938e-04 - val_loss: 0.0010
# Epoch 38/100
# 25/25 [==============================] - 0s 13ms/step - loss: 8.8345e-04 - val_loss: 0.0017
# Epoch 39/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 40/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0011 - val_loss: 8.8699e-04
# Epoch 41/100
# 25/25 [==============================] - 0s 12ms/step - loss: 9.0277e-04 - val_loss: 0.0022
# Epoch 42/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 43/100
# 25/25 [==============================] - 0s 13ms/step - loss: 8.2067e-04 - val_loss: 0.0010
# Epoch 44/100
# 25/25 [==============================] - 0s 12ms/step - loss: 8.2719e-04 - val_loss: 0.0013
# Epoch 45/100
# 25/25 [==============================] - 0s 12ms/step - loss: 8.7696e-04 - val_loss: 8.2191e-04
# Epoch 46/100
# 25/25 [==============================] - 0s 13ms/step - loss: 7.6104e-04 - val_loss: 8.4128e-04
# Epoch 47/100
# 25/25 [==============================] - 0s 12ms/step - loss: 7.1893e-04 - val_loss: 8.2331e-04
# Epoch 48/100
# 25/25 [==============================] - 0s 12ms/step - loss: 7.4508e-04 - val_loss: 8.9491e-04
# Epoch 49/100
# 25/25 [==============================] - 0s 14ms/step - loss: 6.6750e-04 - val_loss: 7.8060e-04
# Epoch 50/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.5688e-04 - val_loss: 7.7988e-04
# Epoch 51/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.3700e-04 - val_loss: 7.6654e-04
# Epoch 52/100
# 25/25 [==============================] - 0s 13ms/step - loss: 6.5577e-04 - val_loss: 8.5166e-04
# Epoch 53/100
# 25/25 [==============================] - 0s 12ms/step - loss: 7.6298e-04 - val_loss: 0.0013
# Epoch 54/100
# 25/25 [==============================] - 0s 12ms/step - loss: 7.2235e-04 - val_loss: 8.8848e-04
# Epoch 55/100
# 25/25 [==============================] - 0s 14ms/step - loss: 6.1725e-04 - val_loss: 7.4775e-04
# Epoch 56/100
# 25/25 [==============================] - 0s 12ms/step - loss: 7.0462e-04 - val_loss: 8.6749e-04
# Epoch 57/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.4129e-04 - val_loss: 8.4735e-04
# Epoch 58/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.1548e-04 - val_loss: 7.1831e-04
# Epoch 59/100
# 25/25 [==============================] - 0s 18ms/step - loss: 6.2918e-04 - val_loss: 0.0010
# Epoch 60/100
# 25/25 [==============================] - 0s 17ms/step - loss: 6.0027e-04 - val_loss: 7.0670e-04
# Epoch 61/100
# 25/25 [==============================] - 0s 18ms/step - loss: 6.4283e-04 - val_loss: 7.9870e-04
# Epoch 62/100
# 25/25 [==============================] - 0s 18ms/step - loss: 7.3657e-04 - val_loss: 0.0014
# Epoch 63/100
# 25/25 [==============================] - 0s 20ms/step - loss: 6.9921e-04 - val_loss: 7.6862e-04
# Epoch 64/100
# 25/25 [==============================] - 0s 17ms/step - loss: 5.7692e-04 - val_loss: 8.1799e-04
# Epoch 65/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.5697e-04 - val_loss: 6.6663e-04
# Epoch 66/100
# 25/25 [==============================] - 0s 13ms/step - loss: 5.7285e-04 - val_loss: 0.0014
# Epoch 67/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.2081e-04 - val_loss: 8.8345e-04
# Epoch 68/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.4399e-04 - val_loss: 9.3523e-04
# Epoch 69/100
# 25/25 [==============================] - 0s 15ms/step - loss: 5.5709e-04 - val_loss: 6.4260e-04
# Epoch 70/100
# 25/25 [==============================] - 1s 21ms/step - loss: 5.9773e-04 - val_loss: 6.2383e-04
# Epoch 71/100
# 25/25 [==============================] - 1s 26ms/step - loss: 6.2070e-04 - val_loss: 6.1414e-04
# Epoch 72/100
# 25/25 [==============================] - 1s 21ms/step - loss: 6.0890e-04 - val_loss: 6.0870e-04
# Epoch 73/100
# 25/25 [==============================] - 0s 13ms/step - loss: 4.9164e-04 - val_loss: 6.0211e-04
# Epoch 74/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.2318e-04 - val_loss: 6.0851e-04
# Epoch 75/100
# 25/25 [==============================] - 0s 13ms/step - loss: 4.7337e-04 - val_loss: 5.8587e-04
# Epoch 76/100
# 25/25 [==============================] - 0s 13ms/step - loss: 5.3137e-04 - val_loss: 5.7901e-04
# Epoch 77/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.6913e-04 - val_loss: 8.4263e-04
# Epoch 78/100
# 25/25 [==============================] - 0s 13ms/step - loss: 5.0189e-04 - val_loss: 5.7783e-04
# Epoch 79/100
# 25/25 [==============================] - 0s 13ms/step - loss: 4.6964e-04 - val_loss: 5.8218e-04
# Epoch 80/100
# 25/25 [==============================] - 0s 13ms/step - loss: 4.6780e-04 - val_loss: 6.3664e-04
# Epoch 81/100
# 25/25 [==============================] - 0s 13ms/step - loss: 5.4853e-04 - val_loss: 9.0003e-04
# Epoch 82/100
# 25/25 [==============================] - 0s 14ms/step - loss: 5.5187e-04 - val_loss: 5.4776e-04
# Epoch 83/100
# 25/25 [==============================] - 0s 13ms/step - loss: 4.5668e-04 - val_loss: 5.4830e-04
# Epoch 84/100
# 25/25 [==============================] - 0s 15ms/step - loss: 4.3359e-04 - val_loss: 6.0408e-04
# Epoch 85/100
# 25/25 [==============================] - 0s 13ms/step - loss: 5.1515e-04 - val_loss: 5.2504e-04
# Epoch 86/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.3713e-04 - val_loss: 6.6075e-04
# Epoch 87/100
# 25/25 [==============================] - 0s 13ms/step - loss: 4.4368e-04 - val_loss: 0.0012
# Epoch 88/100
# 25/25 [==============================] - 0s 13ms/step - loss: 5.9848e-04 - val_loss: 5.0720e-04
# Epoch 89/100
# 25/25 [==============================] - 0s 12ms/step - loss: 4.6954e-04 - val_loss: 5.9366e-04
# Epoch 90/100
# 25/25 [==============================] - 0s 13ms/step - loss: 5.3830e-04 - val_loss: 4.9253e-04
# Epoch 91/100
# 25/25 [==============================] - 0s 13ms/step - loss: 4.4297e-04 - val_loss: 5.0605e-04
# Epoch 92/100
# 25/25 [==============================] - 0s 13ms/step - loss: 4.0706e-04 - val_loss: 6.0485e-04
# Epoch 93/100
# 25/25 [==============================] - 0s 19ms/step - loss: 3.9917e-04 - val_loss: 5.1570e-04
# Epoch 94/100
# 25/25 [==============================] - 0s 17ms/step - loss: 4.1946e-04 - val_loss: 4.9699e-04
# Epoch 95/100
# 25/25 [==============================] - 0s 17ms/step - loss: 4.1990e-04 - val_loss: 6.5024e-04
# Epoch 96/100
# 25/25 [==============================] - 0s 18ms/step - loss: 4.6017e-04 - val_loss: 0.0010
# Epoch 97/100
# 25/25 [==============================] - 0s 18ms/step - loss: 5.3531e-04 - val_loss: 5.6448e-04
# Epoch 98/100
# 25/25 [==============================] - 0s 17ms/step - loss: 6.5565e-04 - val_loss: 4.7565e-04
# Epoch 99/100
# 25/25 [==============================] - 0s 17ms/step - loss: 5.1386e-04 - val_loss: 0.0012
# Epoch 100/100
# 25/25 [==============================] - 0s 13ms/step - loss: 6.2155e-04 - val_loss: 6.4038e-04

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, AdditiveAttention, Permute, Reshape, Multiply

model = Sequential()

# Adding LSTM layers with return_sequences=True
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(units=50, return_sequences=True))

# Adding self-attention mechanism
# The attention mechanism
attention = AdditiveAttention(name='attention_weight')
# Permute and reshape for compatibility
model.add(Permute((2, 1)))
model.add(Reshape((-1, X_train.shape[1])))
attention_result = attention([model.output, model.output])
multiply_layer = Multiply()([model.output, attention_result])
# Return to original shape
model.add(Permute((2, 1)))
model.add(Reshape((-1, 50)))

# Adding a Flatten layer before the final Dense layer
model.add(tf.keras.layers.Flatten())

# Final Dense layer
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=25, validation_split=0.2)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 4s 44ms/step - loss: 0.0589 - val_loss: 0.0102
# Epoch 2/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0084 - val_loss: 0.0052
# Epoch 3/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 4/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 5/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 6/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0060
# Epoch 7/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0044 - val_loss: 0.0065
# Epoch 8/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0045 - val_loss: 0.0057
# Epoch 9/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0039 - val_loss: 0.0046
# Epoch 10/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 11/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0040 - val_loss: 0.0031
# Epoch 12/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0035 - val_loss: 0.0039
# Epoch 13/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 0.0032
# Epoch 14/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0026 - val_loss: 0.0034
# Epoch 15/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 16/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 17/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0024 - val_loss: 0.0036
# Epoch 18/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 19/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 20/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0021 - val_loss: 0.0033
# Epoch 21/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 22/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 23/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 24/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 25/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 26/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 27/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 28/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0047
# Epoch 29/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 30/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 31/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 32/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 33/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0022 - val_loss: 0.0038
# Epoch 34/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 35/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 36/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 37/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 38/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 39/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 40/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 41/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 42/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 43/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 44/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 45/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 46/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 47/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 48/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 49/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 50/100
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 51/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0010 - val_loss: 0.0025
# Epoch 52/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 53/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 54/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 55/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 56/100
# 25/25 [==============================] - 0s 11ms/step - loss: 9.2546e-04 - val_loss: 9.6787e-04
# Epoch 57/100
# 25/25 [==============================] - 0s 10ms/step - loss: 8.3546e-04 - val_loss: 9.7401e-04
# Epoch 58/100
# 25/25 [==============================] - 0s 12ms/step - loss: 7.9378e-04 - val_loss: 0.0011
# Epoch 59/100
# 25/25 [==============================] - 0s 17ms/step - loss: 8.4579e-04 - val_loss: 0.0012
# Epoch 60/100
# 25/25 [==============================] - 0s 14ms/step - loss: 8.6624e-04 - val_loss: 0.0021
# Epoch 61/100
# 25/25 [==============================] - 1s 32ms/step - loss: 0.0017 - val_loss: 8.9930e-04
# Epoch 62/100
# 25/25 [==============================] - 0s 19ms/step - loss: 8.5372e-04 - val_loss: 0.0012
# Epoch 63/100
# 25/25 [==============================] - 1s 28ms/step - loss: 8.4443e-04 - val_loss: 0.0028
# Epoch 64/100
# 25/25 [==============================] - 0s 14ms/step - loss: 9.1120e-04 - val_loss: 9.4820e-04
# Epoch 65/100
# 25/25 [==============================] - 1s 22ms/step - loss: 7.6569e-04 - val_loss: 9.8189e-04
# Epoch 66/100
# 25/25 [==============================] - 0s 12ms/step - loss: 7.4299e-04 - val_loss: 8.5650e-04
# Epoch 67/100
# 25/25 [==============================] - 0s 10ms/step - loss: 7.6508e-04 - val_loss: 0.0015
# Epoch 68/100
# 25/25 [==============================] - 0s 11ms/step - loss: 8.7906e-04 - val_loss: 9.4158e-04
# Epoch 69/100
# 25/25 [==============================] - 0s 10ms/step - loss: 7.6917e-04 - val_loss: 0.0012
# Epoch 70/100
# 25/25 [==============================] - 0s 10ms/step - loss: 7.8691e-04 - val_loss: 9.1566e-04
# Epoch 71/100
# 25/25 [==============================] - 0s 10ms/step - loss: 6.5792e-04 - val_loss: 8.6477e-04
# Epoch 72/100
# 25/25 [==============================] - 0s 12ms/step - loss: 7.0223e-04 - val_loss: 8.1836e-04
# Epoch 73/100
# 25/25 [==============================] - 0s 10ms/step - loss: 7.2959e-04 - val_loss: 0.0010
# Epoch 74/100
# 25/25 [==============================] - 0s 9ms/step - loss: 7.8962e-04 - val_loss: 8.0483e-04
# Epoch 75/100
# 25/25 [==============================] - 0s 9ms/step - loss: 8.4482e-04 - val_loss: 8.1547e-04
# Epoch 76/100
# 25/25 [==============================] - 0s 10ms/step - loss: 6.2689e-04 - val_loss: 8.0162e-04
# Epoch 77/100
# 25/25 [==============================] - 0s 11ms/step - loss: 6.5063e-04 - val_loss: 8.2369e-04
# Epoch 78/100
# 25/25 [==============================] - 0s 11ms/step - loss: 6.2820e-04 - val_loss: 8.0801e-04
# Epoch 79/100
# 25/25 [==============================] - 0s 12ms/step - loss: 6.0445e-04 - val_loss: 0.0011
# Epoch 80/100
# 25/25 [==============================] - 0s 10ms/step - loss: 6.6968e-04 - val_loss: 0.0015
# Epoch 81/100
# 25/25 [==============================] - 0s 9ms/step - loss: 6.5563e-04 - val_loss: 7.8592e-04
# Epoch 82/100
# 25/25 [==============================] - 0s 9ms/step - loss: 6.2454e-04 - val_loss: 8.0090e-04
# Epoch 83/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.5740e-04 - val_loss: 0.0018
# Epoch 84/100
# 25/25 [==============================] - 0s 10ms/step - loss: 6.5138e-04 - val_loss: 7.6168e-04
# Epoch 85/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.7611e-04 - val_loss: 9.0906e-04
# Epoch 86/100
# 25/25 [==============================] - 0s 10ms/step - loss: 6.4474e-04 - val_loss: 9.5652e-04
# Epoch 87/100
# 25/25 [==============================] - 0s 10ms/step - loss: 6.2394e-04 - val_loss: 0.0011
# Epoch 88/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.7665e-04 - val_loss: 7.9657e-04
# Epoch 89/100
# 25/25 [==============================] - 0s 11ms/step - loss: 5.7072e-04 - val_loss: 8.1208e-04
# Epoch 90/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.6065e-04 - val_loss: 7.1097e-04
# Epoch 91/100
# 25/25 [==============================] - 0s 10ms/step - loss: 5.2975e-04 - val_loss: 7.2492e-04
# Epoch 92/100
# 25/25 [==============================] - 0s 12ms/step - loss: 5.3007e-04 - val_loss: 7.0821e-04
# Epoch 93/100
# 25/25 [==============================] - 0s 13ms/step - loss: 5.4191e-04 - val_loss: 0.0013
# Epoch 94/100
# 25/25 [==============================] - 0s 15ms/step - loss: 6.7730e-04 - val_loss: 6.8996e-04
# Epoch 95/100
# 25/25 [==============================] - 0s 15ms/step - loss: 7.4610e-04 - val_loss: 0.0011
# Epoch 96/100
# 25/25 [==============================] - 0s 13ms/step - loss: 5.6072e-04 - val_loss: 0.0011
# Epoch 97/100
# 25/25 [==============================] - 0s 16ms/step - loss: 6.8965e-04 - val_loss: 8.6857e-04
# Epoch 98/100
# 25/25 [==============================] - 0s 15ms/step - loss: 6.9372e-04 - val_loss: 0.0011
# Epoch 99/100
# 25/25 [==============================] - 0s 15ms/step - loss: 6.6930e-04 - val_loss: 7.6739e-04
# Epoch 100/100
# 25/25 [==============================] - 0s 17ms/step - loss: 5.1989e-04 - val_loss: 9.0994e-04

# %%
from keras.layers import BatchNormalization

# Adding Dropout and Batch Normalization
model.add(Dropout(0.2))
model.add(BatchNormalization())

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Assume 'data' is your preprocessed dataset
train_size = int(len(aapl_data) * 0.8)
train_data, test_data = aapl_data[:train_size], aapl_data[train_size:]

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 60, 50)            10400
#
#  lstm_4 (LSTM)               (None, 60, 50)            20200
#
#  permute (Permute)           (None, 50, 60)            0
#
#  reshape (Reshape)           (None, 50, 60)            0
#
#  permute_1 (Permute)         (None, 60, 50)            0
#
#  reshape_1 (Reshape)         (None, 60, 50)            0
#
#  flatten (Flatten)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 1)                 3001
#
#  dropout (Dropout)           (None, 1)                 0
#
#  batch_normalization (Batch  (None, 1)                 4
#  Normalization)
#
# =================================================================
# Total params: 33605 (131.27 KB)
# Trainable params: 33603 (131.26 KB)
# Non-trainable params: 2 (8.00 Byte)
# _________________________________________________________________

# %%
# Assuming X_train and y_train are already defined and preprocessed
history = model.fit(X_train, y_train, epochs=100, batch_size=25, validation_split=0.2)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 8s 41ms/step - loss: 0.9421 - val_loss: 0.3742
# Epoch 2/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.5024 - val_loss: 0.4146
# Epoch 3/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.3182 - val_loss: 0.3293
# Epoch 4/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.2445 - val_loss: 0.3061
# Epoch 5/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.2258 - val_loss: 0.2804
# Epoch 6/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1956 - val_loss: 0.2673
# Epoch 7/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1732 - val_loss: 0.2353
# Epoch 8/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1554 - val_loss: 0.2169
# Epoch 9/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.1373 - val_loss: 0.1927
# Epoch 10/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.1294 - val_loss: 0.1945
# Epoch 11/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.1106 - val_loss: 0.1537
# Epoch 12/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0989 - val_loss: 0.1425
# Epoch 13/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0872 - val_loss: 0.1345
# Epoch 14/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0801 - val_loss: 0.1156
# Epoch 15/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0678 - val_loss: 0.1069
# Epoch 16/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0616 - val_loss: 0.1050
# Epoch 17/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0549 - val_loss: 0.1051
# Epoch 18/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0519 - val_loss: 0.0590
# Epoch 19/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0432 - val_loss: 0.0609
# Epoch 20/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0415 - val_loss: 0.0274
# Epoch 21/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0418 - val_loss: 0.0486
# Epoch 22/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0327 - val_loss: 0.0286
# Epoch 23/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0289 - val_loss: 0.0499
# Epoch 24/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0247 - val_loss: 0.0199
# Epoch 25/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0235 - val_loss: 0.0325
# Epoch 26/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0227 - val_loss: 0.0370
# Epoch 27/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0202 - val_loss: 0.0073
# Epoch 28/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0199 - val_loss: 0.0022
# Epoch 29/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0158 - val_loss: 0.0305
# Epoch 30/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0150 - val_loss: 0.0119
# Epoch 31/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0131 - val_loss: 0.0132
# Epoch 32/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0129 - val_loss: 0.0113
# Epoch 33/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0137 - val_loss: 0.0120
# Epoch 34/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0126 - val_loss: 0.0141
# Epoch 35/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0124 - val_loss: 0.0099
# Epoch 36/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0125 - val_loss: 0.0062
# Epoch 37/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0114 - val_loss: 0.0027
# Epoch 38/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0105 - val_loss: 0.0011
# Epoch 39/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0135 - val_loss: 0.0147
# Epoch 40/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0104 - val_loss: 0.0101
# Epoch 41/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0110 - val_loss: 0.0046
# Epoch 42/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0123 - val_loss: 0.0074
# Epoch 43/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0097 - val_loss: 0.0027
# Epoch 44/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0097 - val_loss: 0.0022
# Epoch 45/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0123 - val_loss: 0.0096
# Epoch 46/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0089 - val_loss: 0.0023
# Epoch 47/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0110 - val_loss: 0.0012
# Epoch 48/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0102 - val_loss: 0.0031
# Epoch 49/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0114 - val_loss: 9.7329e-04
# Epoch 50/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0115 - val_loss: 9.2707e-04
# Epoch 51/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0109 - val_loss: 0.0012
# Epoch 52/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0108 - val_loss: 0.0073
# Epoch 53/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0087 - val_loss: 7.6416e-04
# Epoch 54/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0099 - val_loss: 6.8196e-04
# Epoch 55/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0090 - val_loss: 0.0043
# Epoch 56/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0105 - val_loss: 0.0016
# Epoch 57/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0110 - val_loss: 0.0010
# Epoch 58/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0103 - val_loss: 0.0088
# Epoch 59/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0112 - val_loss: 0.0031
# Epoch 60/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0077 - val_loss: 0.0016
# Epoch 61/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0124 - val_loss: 0.0083
# Epoch 62/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0122 - val_loss: 0.0440
# Epoch 63/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0122 - val_loss: 0.0087
# Epoch 64/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0125 - val_loss: 6.9068e-04
# Epoch 65/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0094 - val_loss: 0.0012
# Epoch 66/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0092 - val_loss: 0.0030
# Epoch 67/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0107 - val_loss: 0.0025
# Epoch 68/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0101 - val_loss: 0.0015
# Epoch 69/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 9.7793e-04
# Epoch 70/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0099 - val_loss: 0.0062
# Epoch 71/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0110 - val_loss: 0.0010
# Epoch 72/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0105 - val_loss: 0.0067
# Epoch 73/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0099 - val_loss: 6.3826e-04
# Epoch 74/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0110 - val_loss: 8.3004e-04
# Epoch 75/100
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0085 - val_loss: 0.0014
# Epoch 76/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0105 - val_loss: 0.0077
# Epoch 77/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0110 - val_loss: 7.0719e-04
# Epoch 78/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0092 - val_loss: 9.4221e-04
# Epoch 79/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0120 - val_loss: 6.5854e-04
# Epoch 80/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0109 - val_loss: 7.0541e-04
# Epoch 81/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0114 - val_loss: 0.0238
# Epoch 82/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0139 - val_loss: 0.0033
# Epoch 83/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0104 - val_loss: 9.2809e-04
# Epoch 84/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0088 - val_loss: 0.0028
# Epoch 85/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0105 - val_loss: 0.0067
# Epoch 86/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0079 - val_loss: 6.5380e-04
# Epoch 87/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0110 - val_loss: 7.6970e-04
# Epoch 88/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0091 - val_loss: 0.0011
# Epoch 89/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0103 - val_loss: 0.0069
# Epoch 90/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0109 - val_loss: 6.1559e-04
# Epoch 91/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0109 - val_loss: 0.0022
# Epoch 92/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0101 - val_loss: 0.0027
# Epoch 93/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0087 - val_loss: 6.3961e-04
# Epoch 94/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0108 - val_loss: 6.2132e-04
# Epoch 95/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0090 - val_loss: 0.0040
# Epoch 96/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0103 - val_loss: 0.0011
# Epoch 97/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0113 - val_loss: 6.8171e-04
# Epoch 98/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0092 - val_loss: 0.0050
# Epoch 99/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0112 - val_loss: 0.0021
# Epoch 100/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0085 - val_loss: 0.0016

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(X_train, y_train, epochs=100, batch_size=25, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0091 - val_loss: 0.0044
# Epoch 2/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0108 - val_loss: 0.0015
# Epoch 3/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0075 - val_loss: 0.0056
# Epoch 4/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0113 - val_loss: 0.0011
# Epoch 5/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0080 - val_loss: 0.0031
# Epoch 6/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0092 - val_loss: 0.0011
# Epoch 7/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0078 - val_loss: 7.8421e-04
# Epoch 8/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0107 - val_loss: 0.0158
# Epoch 9/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0114 - val_loss: 0.0011
# Epoch 10/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0073 - val_loss: 8.1711e-04
# Epoch 11/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0105 - val_loss: 0.0026
# Epoch 12/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0107 - val_loss: 0.0062
# Epoch 13/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0095 - val_loss: 0.0135
# Epoch 14/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0098 - val_loss: 0.0025
# Epoch 15/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0097 - val_loss: 7.9051e-04
# Epoch 16/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0108 - val_loss: 0.0041
# Epoch 17/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0101 - val_loss: 0.0021

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, TensorBoard, CSVLogger

# Callback to save the model periodically
model_checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True, monitor='val_loss')

# Callback to reduce learning rate when a metric has stopped improving
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5)

# Callback for TensorBoard
tensorboard = TensorBoard(log_dir='./logs')

# Callback to log details to a CSV file
csv_logger = CSVLogger('training_log.csv')

# Combining all callbacks
callbacks_list = [early_stopping, model_checkpoint, reduce_lr, tensorboard, csv_logger]

# Fit the model with the callbacks
history = model.fit(X_train, y_train, epochs=100, batch_size=25, validation_split=0.2, callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0093 - val_loss: 0.0040 - lr: 0.0010
# Epoch 2/100
# 11/25 [============>.................] - ETA: 0s - loss: 0.0109
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0094 - val_loss: 7.6967e-04 - lr: 0.0010
# Epoch 3/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0110 - val_loss: 7.3086e-04 - lr: 0.0010
# Epoch 4/100
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0106 - val_loss: 0.0018 - lr: 0.0010
# Epoch 5/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0077 - val_loss: 0.0019 - lr: 0.0010
# Epoch 6/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0103 - val_loss: 0.0054 - lr: 0.0010
# Epoch 7/100
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0096 - val_loss: 6.0421e-04 - lr: 0.0010
# Epoch 8/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0082 - val_loss: 9.6954e-04 - lr: 0.0010
# Epoch 9/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0108 - val_loss: 0.0032 - lr: 0.0010
# Epoch 10/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0104 - val_loss: 0.0035 - lr: 0.0010
# Epoch 11/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0115 - val_loss: 0.0037 - lr: 0.0010
# Epoch 12/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0112 - val_loss: 0.0020 - lr: 0.0010
# Epoch 13/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0104 - val_loss: 0.0016 - lr: 1.0000e-04
# Epoch 14/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0104 - val_loss: 0.0011 - lr: 1.0000e-04
# Epoch 15/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0101 - val_loss: 5.8745e-04 - lr: 1.0000e-04
# Epoch 16/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0093 - val_loss: 6.1029e-04 - lr: 1.0000e-04
# Epoch 17/100
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0082 - val_loss: 0.0022 - lr: 1.0000e-04
# Epoch 18/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0105 - val_loss: 0.0018 - lr: 1.0000e-05
# Epoch 19/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0081 - val_loss: 0.0015 - lr: 1.0000e-05
# Epoch 20/100
# 25/25 [==============================] - 0s 12ms/step - loss: 0.0096 - val_loss: 0.0013 - lr: 1.0000e-05
# Epoch 21/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0096 - val_loss: 0.0012 - lr: 1.0000e-05
# Epoch 22/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0090 - val_loss: 0.0011 - lr: 1.0000e-05
# Epoch 23/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0091 - val_loss: 0.0012 - lr: 1.0000e-06
# Epoch 24/100
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0088 - val_loss: 0.0011 - lr: 1.0000e-06
# Epoch 25/100
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0108 - val_loss: 0.0011 - lr: 1.0000e-06

# %%
# Convert X_test and y_test to Numpy arrays if they are not already
X_test = np.array(X_test)
y_test = np.array(y_test)

# Ensure X_test is reshaped similarly to how X_train was reshaped
# This depends on how you preprocessed the training data
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Now evaluate the model on the test data
test_loss = model.evaluate(X_test, y_test)
print("Test Loss: ", test_loss)
# Out:
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0059
# Test Loss:  0.005890408530831337

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Making predictions
y_pred = model.predict(X_test)

# Calculating MAE and RMSE
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

print("Mean Absolute Error: ", mae)
print("Root Mean Square Error: ", rmse)
# Out:
# 6/6 [==============================] - 1s 4ms/step
# Mean Absolute Error:  0.07416603974141815
# Root Mean Square Error:  0.07674899945218956

# %%
import yfinance as yf
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Fetching the latest 60 days of AAPL stock data
data = yf.download('AAPL', period='3mo', interval='1d')

# Selecting the 'Close' price and converting to numpy array
closing_prices = data['Close'].values

# Scaling the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(closing_prices.reshape(-1,1))

# Since we need the last 60 days to predict the next day, we reshape the data accordingly
X_latest = np.array([scaled_data[-60:].reshape(60)])

# Reshaping the data for the model (adding batch dimension)
X_latest = np.reshape(X_latest, (X_latest.shape[0], X_latest.shape[1], 1))

# Making predictions for the next 4 candles
predicted_stock_price = model.predict(X_latest)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

print("Predicted Stock Prices for the next 4 days: ", predicted_stock_price)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 0s 90ms/step
# Predicted Stock Prices for the next 4 days:  [[202.845]]

# %%
import yfinance as yf
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Fetch the latest 60 days of AAPL stock data
data = yf.download('AAPL', period='3mo', interval='1d')

# Select 'Close' price and scale it
closing_prices = data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(closing_prices)

# Predict the next 4 days iteratively
predicted_prices = []
current_batch = scaled_data[-60:].reshape(1, 60, 1)  # Most recent 60 days

for i in range(4):  # Predicting 4 days
    # Get the prediction (next day)
    next_prediction = model.predict(current_batch)

    # Reshape the prediction to fit the batch dimension
    next_prediction_reshaped = next_prediction.reshape(1, 1, 1)

    # Append the prediction to the batch used for predicting
    current_batch = np.append(current_batch[:, 1:, :], next_prediction_reshaped, axis=1)

    # Inverse transform the prediction to the original price scale
    predicted_prices.append(scaler.inverse_transform(next_prediction)[0, 0])

print("Predicted Stock Prices for the next 4 days: ", predicted_prices)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted Stock Prices for the next 4 days:  [202.845, 200.02847, 198.17693, 197.62335]

# %%
# !pip install mplfinance -qqq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.8 MB/s eta 0:00:00

# %%
import pandas as pd
import mplfinance as mpf
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame with the fetched AAPL stock data
# Make sure it contains Open, High, Low, Close, and Volume columns

# Creating a list of dates for the predictions
last_date = data.index[-1]
next_day = last_date + pd.Timedelta(days=1)
prediction_dates = pd.date_range(start=next_day, periods=4)

# Assuming 'predicted_prices' is your list of predicted prices for the next 4 days
predictions_df = pd.DataFrame(index=prediction_dates, data=predicted_prices, columns=['Close'])

# Plotting the actual data with mplfinance
mpf.plot(data, type='candle', style='charles', volume=True)

# Overlaying the predicted data
plt.figure(figsize=(10,6))
plt.plot(predictions_df.index, predictions_df['Close'], linestyle='dashed', marker='o', color='red')

plt.title("AAPL Stock Price with Predicted Next 4 Days")
plt.show()

# %%
import pandas as pd
import mplfinance as mpf
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt

# Fetch the latest 60 days of AAPL stock data
data = yf.download('AAPL', period='3mo', interval='1d') # Fetch 64 days to display last 60 days in the chart

# Select 'Close' price and scale it
closing_prices = data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(closing_prices)

# Predict the next 4 days iteratively
predicted_prices = []
current_batch = scaled_data[-60:].reshape(1, 60, 1)  # Most recent 60 days

for i in range(4):  # Predicting 4 days
    next_prediction = model.predict(current_batch)
    next_prediction_reshaped = next_prediction.reshape(1, 1, 1)
    current_batch = np.append(current_batch[:, 1:, :], next_prediction_reshaped, axis=1)
    predicted_prices.append(scaler.inverse_transform(next_prediction)[0, 0])

# Creating a list of dates for the predictions
last_date = data.index[-1]
next_day = last_date + pd.Timedelta(days=1)
prediction_dates = pd.date_range(start=next_day, periods=4)

# Adding predictions to the DataFrame
predicted_data = pd.DataFrame(index=prediction_dates, data=predicted_prices, columns=['Close'])

# Combining both actual and predicted data
combined_data = pd.concat([data['Close'], predicted_data['Close']])
combined_data = combined_data[-64:] # Last 60 days of actual data + 4 days of predictions

# Plotting the data
plt.figure(figsize=(10,6))
plt.plot(combined_data, linestyle='-', marker='o', color='blue')
plt.title("AAPL Stock Price: Last 60 Days and Next 4 Days Predicted")
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 29ms/step

# %%
import pandas as pd
import mplfinance as mpf
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt

# Fetch the latest 60 days of AAPL stock data
data = yf.download('AAPL', period='3mo', interval='1d') # Fetch 64 days to display last 60 days in the chart

# Select 'Close' price and scale it
closing_prices = data['Close'].values.reshape(-1, 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(closing_prices)

# Predict the next 4 days iteratively
predicted_prices = []
current_batch = scaled_data[-60:].reshape(1, 60, 1)  # Most recent 60 days

for i in range(4):  # Predicting 4 days
    next_prediction = model.predict(current_batch)
    next_prediction_reshaped = next_prediction.reshape(1, 1, 1)
    current_batch = np.append(current_batch[:, 1:, :], next_prediction_reshaped, axis=1)
    predicted_prices.append(scaler.inverse_transform(next_prediction)[0, 0])

# Creating a list of dates for the predictions
last_date = data.index[-1]
next_day = last_date + pd.Timedelta(days=1)
prediction_dates = pd.date_range(start=next_day, periods=4)

# Adding predictions to the DataFrame
predicted_data = pd.DataFrame(index=prediction_dates, data=predicted_prices, columns=['Close'])

# Combining both actual and predicted data
combined_data = pd.concat([data['Close'], predicted_data['Close']])
combined_data = combined_data[-64:] # Last 60 days of actual data + 4 days of predictions

# Plotting the actual data
plt.figure(figsize=(10,6))
plt.plot(data.index[-60:], data['Close'][-60:], linestyle='-', marker='o', color='blue', label='Actual Data')

# Plotting the predicted data
plt.plot(prediction_dates, predicted_prices, linestyle='-', marker='o', color='red', label='Predicted Data')

plt.title("AAPL Stock Price: Last 60 Days and Next 4 Days Predicted")
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime, timedelta


def predict_stock_price(input_date):
    # Check if the input date is a valid date format
    try:
        input_date = pd.to_datetime(input_date)
    except ValueError:
        print("Invalid Date Format. Please enter date in YYYY-MM-DD format.")
        return

    # Fetch data from yfinance
    end_date = input_date
    start_date = input_date - timedelta(days=90)  # Fetch more days to ensure we have 60 trading days
    data = yf.download('AAPL', start=start_date, end=end_date)

    if len(data) < 60:
        print("Not enough historical data to make a prediction. Try an earlier date.")
        return

    # Prepare the data
    closing_prices = data['Close'].values[-60:]  # Last 60 days
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(closing_prices.reshape(-1, 1))

    # Make predictions
    predicted_prices = []
    current_batch = scaled_data.reshape(1, 60, 1)

    for i in range(4):  # Predicting 4 days
        next_prediction = model.predict(current_batch)
        next_prediction_reshaped = next_prediction.reshape(1, 1, 1)
        current_batch = np.append(current_batch[:, 1:, :], next_prediction_reshaped, axis=1)
        predicted_prices.append(scaler.inverse_transform(next_prediction)[0, 0])

    # Output the predictions
    for i, price in enumerate(predicted_prices, 1):
        print(f"Day {i} prediction: {price}")

# Example use
user_input = input("Enter a date (YYYY-MM-DD) to predict AAPL stock for the next 4 days: ")
predict_stock_price(user_input)
# Out:
# Enter a date (YYYY-MM-DD) to predict AAPL stock for the next 4 days: 2024-06-23
# [*********************100%%**********************]  1 of 1 completed
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# Day 1 prediction: 202.84500122070312
# Day 2 prediction: 200.02847290039062
# Day 3 prediction: 198.1769256591797
# Day 4 prediction: 197.62335205078125

# %%
---------------------------------------------------------------------------
ValueError                                Traceback (most recent call last)
<ipython-input-18-24a063037cda> in <cell line: 16>()
     14 # Transpose the DataFrame to have states as rows and their respective rates as the columns
     15 unemp_data = unemp_data.T
---> 16 unemp_data.columns = ['UnemploymentRate']
     17
     18 # Convert the UnemploymentRate column to numeric

4 frames
/usr/local/lib/python3.10/dist-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
     68
     69         elif new_len != old_len:
---> 70             raise ValueError(
     71                 f"Length mismatch: Expected axis has {old_len} elements, new "
     72                 f"values have {new_len} elements"

ValueError: Length mismatch: Expected axis has 416 elements, new values have 1 elements
# Out:
#   File "<ipython-input-30-ea846a9aa4f2>", line 3
#     <ipython-input-18-24a063037cda> in <cell line: 16>()
#                        ^
# SyntaxError: invalid decimal literal
