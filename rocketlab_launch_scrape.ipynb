# %%
pip install requests beautifulsoup4 pandas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the Wikipedia page
url = "https://en.wikipedia.org/wiki/List_of_Electron_launches"

# Sending a request to fetch the content of the page
response = requests.get(url)
response.raise_for_status()  # Check if the request was successful

# Parsing the page content with BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# Finding the table with the list of launches
tables = soup.find_all("table", {"class": "wikitable"})

# Extracting data from the tables
launch_data = []
headers = []
for table in tables:
    current_headers = [header.get_text(strip=True) for header in table.find_all("th")]
    if len(current_headers) > len(headers):
        headers = current_headers
    rows = table.find_all("tr")
    for row in rows:
        cells = row.find_all(["th", "td"])
        if len(cells) > 0:
            launch_data.append([cell.get_text(strip=True) for cell in cells])

# Determine the maximum number of columns in the data rows
max_columns = max(len(row) for row in launch_data)

# Ensure all rows have the same number of columns
for row in launch_data:
    while len(row) < max_columns:
        row.append("")

# Create DataFrame
df = pd.DataFrame(launch_data)

# Set the headers
df.columns = headers[:max_columns]

# Display the DataFrame
print(df)

# Save the DataFrame to a CSV file
df.to_csv("electron_launches.csv", index=False)

# %%
import pandas as pd

# Load the CSV file
file_path = "electron_launches.csv"
df = pd.read_csv(file_path)

# Drop any completely empty rows
df.dropna(how='all', inplace=True)

# Function to check if a row is valid (i.e., it contains a flight number and other key data points)
def is_valid_row(row):
    return row['FlightNo.'].isdigit()

# Filter out rows that are not valid
df = df[df.apply(is_valid_row, axis=1)]

# Reset index after filtering
df.reset_index(drop=True, inplace=True)

# Strip whitespace from headers and rows
df.columns = df.columns.str.strip()
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# Display the cleaned DataFrame
print("Cleaned DataFrame:")
print(df.head(10))

# Save the cleaned DataFrame to a new CSV file
cleaned_file_path_final = "electron_launches_cleaned_final.csv"
df.to_csv(cleaned_file_path_final, index=False)

print(f"Cleaned data has been saved to {cleaned_file_path_final}")
# Out:
# Cleaned DataFrame:
#   FlightNo.                                 Name  \
# 0         1                        "It's a Test"
# 1         2                      "Still Testing"
# 2         3             "It's Business Time"[19]
# 3         4        "This One's ForPickering"[28]
# 4         5                  "Two Thumbs Up"[31]
# 5         6  "That's a Funny Looking Cactus"[36]
# 6         7                       "Make it Rain"
# 7         8                  "Look Ma, No Hands"
# 8         9                  "As the Crow Flies"
# 9        10             "Running Out Of Fingers"
#
#                    Date/time(UTC)           Launch site  \
# 0           25 May 2017, 04:20[3]          Mahia, LC-1A
# 1       21 January 2018, 01:43[6]          Mahia, LC-1A
# 2         11 November 2018, 03:50  Mahia, LC-1A[19][20]
# 3      16 December 2018, 06:33[7]          Mahia, LC-1A
# 4        28 March 2019, 23:27[31]          Mahia, LC-1A
# 5           5 May 2019, 06:00[37]          Mahia, LC-1A
# 6         29 June 2019, 04:30[40]          Mahia, LC-1A
# 7       19 August 2019, 12:12[47]          Mahia, LC-1A
# 8      17 October 2019, 01:22[50]          Mahia, LC-1A
# 9  6 December 2019, 08:18[54][55]          Mahia, LC-1A
#
#                                              Payload  \
# 0                                                NaN
# 1            Dove PioneerLemur-2× 2Humanity Star[10]
# 2  Lemur-2× 2CICERO[21]IRVINE01[22]NABEO[22]Proxi...
# 3  ELaNa-19ALBusCeREsCHOMPTTCubeSailDaVinciISXNMT...
# 4                                           R3D2[32]
# 5                 STP-27RDSPARC-1Falcon ODEHarbinger
# 6  BlackSky Global 3Prometheusx 2ACRUX-1SpaceBEE8...
# 7  Breizh Recon Orbiter (BRO-1)BlackSky Global 4E...
# 8                                       Palisade[51]
# 9  ATL-1Fossasat-1NOOR-1A(Unicorn 2B)NOOR-1B(Unic...
#
#                         Payload Mass           Destination  \
# 0                                NaN        500 km, 85°LEO
# 1                  13 kg (29 lb)[11]      400 km, 82.9°LEO
# 2    Approx 45 kilograms (99 lb)[11]        500 km, 85°LEO
# 3                 78 kg (172 lb)[29]        500 km, 85°LEO
# 4                150 kg (330 lb)[33]      425 km, 39.5°LEO
# 5         180 kilograms (400 lb)[37]        500 km, 40°LEO
# 6          80 kilograms (180 lb)[44]        450 km, 45°LEO
# 7  Approx. 80 kilograms (180 lb)[11]      510 km, 94.8°LEO
# 8   Approx. 20 kilograms (44 lb)[11]     1200 km, 87.9°LEO
# 9  Approx. 77 kilograms (170 lb)[11]  385 x 400 km, 97°LEO
#
#                                          Customer(s) Launch outcome  \
# 0                            Rocket Lab(flight test)        Failure
# 1                            Planet LabsSpire Global        Success
# 2  Spire GlobalGeoOpticsIrvine CubeSat STEM Progr...        Success
# 3                                           NASA[30]        Success
# 4                                              DARPA        Success
# 5                                     U.S. Air Force        Success
# 6  BlackSky viaSpaceflight Inc.USSOCOMMelbourne S...        Success
# 7        UnseenLabsBlackSky viaSpaceflight Inc.AFSPC        Success
# 8                                  Astro Digital[52]        Success
# 9  Advanced Technology of LaserFossa SystemsStara...        Success
#
#                Booster recovery
# 0                    No attempt
# 1                    No attempt
# 2                    No attempt
# 3                    No attempt
# 4                    No attempt
# 5                    No attempt
# 6                    No attempt
# 7                    No attempt
# 8                    No attempt
# 9  Controlled (atmosphere test)
# Cleaned data has been saved to electron_launches_cleaned_final.csv
# C:\Users\alexl\AppData\Local\Temp\ipykernel_2220\4040710189.py:22: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
import pandas as pd
import re

# Load the CSV file
file_path = "electron_launches_cleaned_final.csv"
df = pd.read_csv(file_path)

# Function to clean special characters
def clean_special_characters(text):
    if isinstance(text, str):
        return text.encode('ascii', 'ignore').decode('ascii')
    return text

# Function to remove references like [20] from the text
def remove_references(text):
    if isinstance(text, str):
        return re.sub(r'\[\d+\]', '', text)
    return text

# Function to extract KG values from the payload mass, considering both 'kg' and 'kilograms'
def extract_kg(text):
    if isinstance(text, str):
        match = re.search(r'(\d+)\s*(kg|kilograms)', text.lower())
        return match.group(1) + ' kg' if match else ''
    return ''

# Apply the cleaning functions to the DataFrame
df = df.applymap(clean_special_characters)
df = df.applymap(remove_references)
df['Payload Mass'] = df['Payload Mass'].apply(extract_kg)

# Strip whitespace from headers and rows
df.columns = df.columns.str.strip()
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# Save the cleaned DataFrame to a new CSV file
cleaned_file_path_final_v4 = "electron_launches_cleaned_final_v4.csv"
df.to_csv(cleaned_file_path_final_v4, index=False)

# Display the first few rows of the cleaned DataFrame
cleaned_df_final_head = df.head(20)
print(cleaned_df_final_head)

# Path to the cleaned file
cleaned_file_path_final_v4
# Out:
#     FlightNo. LaunchType                                Name  \
# 0           1    Orbital                       "It's a Test"
# 1           2    Orbital                     "Still Testing"
# 2           3    Orbital                "It's Business Time"
# 3           4    Orbital           "This One's ForPickering"
# 4           5    Orbital                     "Two Thumbs Up"
# 5           6    Orbital     "That's a Funny Looking Cactus"
# 6           7    Orbital                      "Make it Rain"
# 7           8    Orbital                 "Look Ma, No Hands"
# 8           9    Orbital                 "As the Crow Flies"
# 9          10    Orbital            "Running Out Of Fingers"
# 10         11    Orbital                "Birds of a Feather"
# 11         12    Orbital                 "Don't Stop Me Now"
# 12         13    Orbital          "Pics Or It Didn't Happen"
# 13         14    Orbital  "I Can't Believe It's Not Optical"
# 14         15    Orbital                          "In Focus"
# 15         16    Orbital                  "Return To Sender"
# 16         17    Orbital            "The Owl's Night Begins"
# 17         18    Orbital      "Another One Leaves The Crust"
# 18         19    Orbital                "They Go Up So Fast"
# 19         20    Orbital               "Running Out Of Toes"
#
#               Date/time(UTC)   Launch site  \
# 0         25 May 2017, 04:20  Mahia, LC-1A
# 1     21 January 2018, 01:43  Mahia, LC-1A
# 2    11 November 2018, 03:50  Mahia, LC-1A
# 3    16 December 2018, 06:33  Mahia, LC-1A
# 4       28 March 2019, 23:27  Mahia, LC-1A
# 5          5 May 2019, 06:00  Mahia, LC-1A
# 6        29 June 2019, 04:30  Mahia, LC-1A
# 7      19 August 2019, 12:12  Mahia, LC-1A
# 8     17 October 2019, 01:22  Mahia, LC-1A
# 9     6 December 2019, 08:18  Mahia, LC-1A
# 10    31 January 2020, 02:56  Mahia, LC-1A
# 11     13 June 2020,05:12:12  Mahia, LC-1A
# 12       4 July 202021:19:36  Mahia, LC-1A
# 13    31 August 202003:05:47  Mahia, LC-1A
# 14   28 October 202021:21:27  Mahia, LC-1A
# 15  20 November 202002:20:01  Mahia, LC-1A
# 16  15 December 202010:09:27  Mahia, LC-1A
# 17   20 January 202107:26:00  Mahia, LC-1A
# 18        22 March 202122:30  Mahia, LC-1A
# 19          15 May 202111:11  Mahia, LC-1A
#
#                                               Payload Payload Mass  \
# 0                                                 NaN
# 1                  Dove PioneerLemur-2 2Humanity Star        13 kg
# 2               Lemur-2 2CICEROIRVINE01NABEOProxima 2        45 kg
# 3   ELaNa-19ALBusCeREsCHOMPTTCubeSailDaVinciISXNMT...        78 kg
# 4                                                R3D2       150 kg
# 5                  STP-27RDSPARC-1Falcon ODEHarbinger       180 kg
# 6   BlackSky Global 3Prometheusx 2ACRUX-1SpaceBEE8...        80 kg
# 7   Breizh Recon Orbiter (BRO-1)BlackSky Global 4E...        80 kg
# 8                                            Palisade        20 kg
# 9   ATL-1Fossasat-1NOOR-1A(Unicorn 2B)NOOR-1B(Unic...        77 kg
# 10                                           NROL-151
# 11  Classified payloads x 3 (USA-301, 302, 303) (N...
# 12                    CE-SAT-IBSuperDove x 5Faraday 1        75 kg
# 13                         SequoiaPhoton(First Light)       100 kg
# 14                            SuperDove x 9CE-SAT-IIB        72 kg
# 15  Dragracer ADragracer BBRO-2BRO-3APSS-1 (Te Wak...       200 kg
# 16                                             StriX-       150 kg
# 17                                              GMS-T        50 kg
# 18  BlackSky Global 9Centauri 3Myriota 7Veery Hatc...
# 19                           BlackSky-10, BlackSky-11       120 kg
#
#                 Destination  \
# 0              500km, 85LEO
# 1           400 km, 82.9LEO
# 2              500km, 85LEO
# 3              500km, 85LEO
# 4            425km, 39.5LEO
# 5              500km, 40LEO
# 6             450 km, 45LEO
# 7           510 km, 94.8LEO
# 8           1200km, 87.9LEO
# 9        385 x 400km, 97LEO
# 10   590km x 610km, 70.9LEO
# 11     570*590 km, 97.75LEO
# 12          500 km, 97.5SSO
# 13            500 km, 45LEO
# 14          500 km, 97.5SSO
# 15          500 km, 97.3SSO
# 16           500km, 97.3SSO
# 17           1200 km, 90LEO
# 18  450 km and 550km, 45LEO
# 19            430 km, 50LEO
#
#                                           Customer(s) Launch outcome  \
# 0                             Rocket Lab(flight test)        Failure
# 1                             Planet LabsSpire Global        Success
# 2   Spire GlobalGeoOpticsIrvine CubeSat STEM Progr...        Success
# 3                                                NASA        Success
# 4                                               DARPA        Success
# 5                                      U.S. Air Force        Success
# 6   BlackSky viaSpaceflight Inc.USSOCOMMelbourne S...        Success
# 7         UnseenLabsBlackSky viaSpaceflight Inc.AFSPC        Success
# 8                                       Astro Digital        Success
# 9   Advanced Technology of LaserFossa SystemsStara...        Success
# 10                     National Reconnaissance Office        Success
# 11  NRO,Boston University/NASAandUniversity of New...        Success
# 12      Canon ElectronicsPlanet LabsIn-Space Missions        Failure
# 13                                      Capella Space        Success
# 14   Planet LabsSpaceflight, Inc.forCanon Electronics        Success
# 15  TriSept Corp.UnseenLabsTe Pnaha tea - Auckland...        Success
# 16                                        Synspective        Success
# 17                                                OHB        Success
# 18  BlackSky viaSpaceflight Inc.Fleet SpaceMyriota...        Success
# 19           BlackSky viaSpaceflight Industries, Inc.        Failure
#
#                 Booster recovery
# 0                     No attempt
# 1                     No attempt
# 2                     No attempt
# 3                     No attempt
# 4                     No attempt
# 5                     No attempt
# 6                     No attempt
# 7                     No attempt
# 8                     No attempt
# 9   Controlled (atmosphere test)
# 10  Controlled (atmosphere test)
# 11                    No attempt
# 12                    No attempt
# 13                    No attempt
# 14                    No attempt
# 15       Success (Ocean landing)
# 16                    No attempt
# 17                    No attempt
# 18                    No attempt
# 19       Success (Ocean landing)
# C:\Users\alexl\AppData\Local\Temp\ipykernel_2220\1154985827.py:28: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(clean_special_characters)
# C:\Users\alexl\AppData\Local\Temp\ipykernel_2220\1154985827.py:29: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(remove_references)
# C:\Users\alexl\AppData\Local\Temp\ipykernel_2220\1154985827.py:34: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
# 'electron_launches_cleaned_final_v4.csv'
